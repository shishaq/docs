# %% [markdown]
# <a href="https://colab.research.google.com/github/shishaq/docs/blob/main/Colab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df_unbranded = pd.read_excel('/content/drive/My Drive/WIP Analysis/Kyle_Unbranded Search by Week - by page.xlsx')
df_unbranded.head()
# Out:
#                                           Unnamed: 0           Unnamed: 1  \
# 0                                                NaN                  NaN
# 1                                      Sum of Clicks        Column Labels
# 2                                         Row Labels  2024-06-09 00:00:00
# 3                                         GBP Clicks                  237
# 4  https://www.codapet.com/cities/nashville-tn?ut...                   18
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2024-06-16 00:00:00  2024-06-23 00:00:00  2024-06-30 00:00:00
# 3                  222                  287                  230
# 4                   18                   24                   26
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# ...
